# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
from TrainData import TrainData

# %%
df = pd.read_csv("data/train.csv")
print(pd.DataFrame.info(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB
# None

# %%
df = df.drop("Id", axis=1)
df = df[np.isfinite(df["SalePrice"])]
print(pd.DataFrame.info(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(34), object(43)
# memory usage: 923.9+ KB
# None

# %%
#print(pd.DataFrame.describe(train))

# %%
train, validation = np.split(df.sample(frac=1), [int(.8*len(df))])
print train.shape
print validation.shape
# Out:
# (1168, 80)
# (292, 80)

# %%
td = TrainData(train)
testData = TestData(test)

# %%
# Out:
# {('Alley', nan): 184930.4034608379,
#  ('Alley', 'Grvl'): 121242.78048780488,
#  ('Alley', 'Pave'): 165862.4827586207,
#  ('BldgType', '1Fam'): 187414.41505595116,
#  ('BldgType', '2fmCon'): 116793.18181818182,
#  ('BldgType', 'Duplex'): 131926.41860465117,
#  ('BldgType', 'Twnhs'): 133127.58620689655,
#  ('BldgType', 'TwnhsE'): 181353.76923076922,
#  ('BsmtCond', nan): 108829.0,
#  ('BsmtCond', 'Fa'): 115193.05555555556,
#  ('BsmtCond', 'Gd'): 215070.4716981132,
#  ('BsmtCond', 'Po'): 67000.0,
#  ('BsmtCond', 'TA'): 185292.35119617224,
#  ('BsmtExposure', nan): 111289.91176470589,
#  ('BsmtExposure', 'Av'): 207266.37158469946,
#  ('BsmtExposure', 'Gd'): 262627.3644859813,
#  ('BsmtExposure', 'Mn'): 193637.71875,
#  ('BsmtExposure', 'No'): 166351.0655080214,
#  ('BsmtFinType1', nan): 108829.0,
#  ('BsmtFinType1', 'ALQ'): 160942.67955801106,
#  ('BsmtFinType1', 'BLQ'): 148230.60169491524,
#  ('BsmtFinType1', 'GLQ'): 236400.82738095237,
#  ('BsmtFinType1', 'LwQ'): 154074.1935483871,
#  ('BsmtFinType1', 'Rec'): 149874.94949494948,
#  ('BsmtFinType1', 'Unf'): 173452.6784660767,
#  ('BsmtFinType2', nan): 113981.08823529411,
#  ('BsmtFinType2', 'ALQ'): 220785.7142857143,
#  ('BsmtFinType2', 'BLQ'): 148870.82142857142,
#  ('BsmtFinType2', 'GLQ'): 177211.53846153847,
#  ('BsmtFinType2', 'LwQ'): 166359.0909090909,
#  ('BsmtFinType2', 'Rec'): 170060.11904761905,
#  ('BsmtFinType2', 'Unf'): 186019.60557768925,
#  ('BsmtQual', nan): 108829.0,
#  ('BsmtQual', 'Ex'): 325271.59,
#  ('BsmtQual', 'Fa'): 117404.32142857143,
#  ('BsmtQual', 'Gd'): 204191.67137096773,
#  ('BsmtQual', 'TA'): 141193.03913894325,
#  ('CentralAir', 'N'): 102475.11111111111,
#  ('CentralAir', 'Y'): 187460.1651459854,
#  ('Condition1', 'Artery'): 134700.0,
#  ('Condition1', 'Feedr'): 145301.72727272726,
#  ('Condition1', 'Norm'): 186338.19980217607,
#  ('Condition1', 'PosA'): 231000.0,
#  ('Condition1', 'PosN'): 220269.23076923078,
#  ('Condition1', 'RRAe'): 138400.0,
#  ('Condition1', 'RRAn'): 159689.72222222222,
#  ('Condition1', 'RRNe'): 190750.0,
#  ('Condition1', 'RRNn'): 204666.66666666666,
#  ('Condition2', 'Artery'): 106500.0,
#  ('Condition2', 'Feedr'): 107875.0,
#  ('Condition2', 'Norm'): 182340.8764044944,
#  ('Condition2', 'PosA'): 325000.0,
#  ('Condition2', 'PosN'): 284875.0,
#  ('Condition2', 'RRAe'): 190000.0,
#  ('Condition2', 'RRAn'): 136905.0,
#  ('Electrical', 'FuseA'): 122070.61538461539,
#  ('Electrical', 'FuseF'): 107477.95238095238,
#  ('Electrical', 'FuseP'): 97333.33333333333,
#  ('Electrical', 'Mix'): 67000.0,
#  ('Electrical', 'SBrkr'): 188447.8910798122,
#  ('ExterCond', 'Ex'): 325000.0,
#  ('ExterCond', 'Fa'): 104966.52631578948,
#  ('ExterCond', 'Gd'): 169988.99122807017,
#  ('ExterCond', 'TA'): 184851.48936170212,
#  ('ExterQual', 'Ex'): 371792.3658536585,
#  ('ExterQual', 'Fa'): 84681.18181818182,
#  ('ExterQual', 'Gd'): 233888.43969849247,
#  ('ExterQual', 'TA'): 144250.65459610027,
#  ('Exterior1st', 'AsbShng'): 108541.82352941176,
#  ('Exterior1st', 'AsphShn'): 100000.0,
#  ('Exterior1st', 'BrkComm'): 71000.0,
#  ('Exterior1st', 'BrkFace'): 197760.2564102564,
#  ('Exterior1st', 'CBlock'): 105000.0,
#  ('Exterior1st', 'CemntBd'): 236564.82142857142,
#  ('Exterior1st', 'HdBoard'): 165698.85555555555,
#  ('Exterior1st', 'ImStucc'): 262000.0,
#  ('Exterior1st', 'MetalSd'): 150472.0350877193,
#  ('Exterior1st', 'Plywood'): 175168.91860465117,
#  ('Exterior1st', 'Stone'): 287000.0,
#  ('Exterior1st', 'Stucco'): 159138.55,
#  ('Exterior1st', 'VinylSd'): 214959.52109181142,
#  ('Exterior1st', 'Wd Sdng'): 150497.19642857142,
#  ('Exterior1st', 'WdShing'): 155319.63636363635,
#  ('Exterior2nd', 'AsbShng'): 116013.1875,
#  ('Exterior2nd', 'AsphShn'): 100000.0,
#  ('Exterior2nd', 'Brk Cmn'): 118000.0,
#  ('Exterior2nd', 'BrkFace'): 206872.5,
#  ('Exterior2nd', 'CBlock'): 105000.0,
#  ('Exterior2nd', 'CmentBd'): 233716.60714285713,
#  ('Exterior2nd', 'HdBoard'): 171024.07142857142,
#  ('Exterior2nd', 'ImStucc'): 272783.3333333333,
#  ('Exterior2nd', 'MetalSd'): 150886.85542168675,
#  ('Exterior2nd', 'Other'): 319000.0,
#  ('Exterior2nd', 'Plywood'): 165068.98319327732,
#  ('Exterior2nd', 'Stone'): 157041.33333333334,
#  ('Exterior2nd', 'Stucco'): 150479.77272727274,
#  ('Exterior2nd', 'VinylSd'): 215954.82994923857,
#  ('Exterior2nd', 'Wd Sdng'): 147931.4779874214,
#  ('Exterior2nd', 'Wd Shng'): 167438.70967741936,
#  ('Fence', nan): 188862.69799366422,
#  ('Fence', 'GdPrv'): 180147.04545454544,
#  ('Fence', 'GdWo'): 140714.94871794872,
#  ('Fence', 'MnPrv'): 149407.03053435116,
#  ('Fence', 'MnWw'): 142128.57142857142,
#  ('FireplaceQu', nan): 141912.36178107606,
#  ('FireplaceQu', 'Ex'): 334110.5263157895,
#  ('FireplaceQu', 'Fa'): 167782.6923076923,
#  ('FireplaceQu', 'Gd'): 225721.47588424437,
#  ('FireplaceQu', 'Po'): 126310.76470588235,
#  ('FireplaceQu', 'TA'): 208151.0703125,
#  ('Foundation', 'BrkTil'): 134079.53913043477,
#  ('Foundation', 'CBlock'): 150262.17296222664,
#  ('Foundation', 'PConc'): 226712.2183908046,
#  ('Foundation', 'Slab'): 112713.09523809524,
#  ('Foundation', 'Stone'): 145955.2,
#  ('Foundation', 'Wood'): 196500.0,
#  ('Functional', 'Maj1'): 169027.4,
#  ('Functional', 'Maj2'): 85800.0,
#  ('Functional', 'Min1'): 146627.08333333334,
#  ('Functional', 'Min2'): 144816.62068965516,
#  ('Functional', 'Mod'): 174957.14285714287,
#  ('Functional', 'Sev'): 129000.0,
#  ('Functional', 'Typ'): 184717.18248847927,
#  ('GarageCond', nan): 102788.70967741935,
#  ('GarageCond', 'Fa'): 115254.54838709677,
#  ('GarageCond', 'Gd'): 209794.0,
#  ('GarageCond', 'Po'): 110500.0,
#  ('GarageCond', 'TA'): 189075.92857142858,
#  ('GarageFinish', nan): 102788.70967741935,
#  ('GarageFinish', 'Fin'): 243767.6726618705,
#  ('GarageFinish', 'RFn'): 202513.15317919076,
#  ('GarageFinish', 'Unf'): 142374.86514522822,
#  ('GarageQual', nan): 102788.70967741935,
#  ('GarageQual', 'Ex'): 475000.0,
#  ('GarageQual', 'Fa'): 126712.70731707317,
#  ('GarageQual', 'Gd'): 223679.16666666666,
#  ('GarageQual', 'Po'): 102000.0,
#  ('GarageQual', 'TA'): 188479.31238095238,
#  ('GarageType', nan): 102788.70967741935,
#  ('GarageType', '2Types'): 142175.0,
#  ('GarageType', 'Attchd'): 203295.37552742616,
#  ('GarageType', 'Basment'): 151716.2,
#  ('GarageType', 'BuiltIn'): 265706.1323529412,
#  ('GarageType', 'CarPort'): 110207.375,
#  ('GarageType', 'Detchd'): 133748.39333333334,
#  ('Heating', 'Floor'): 72500.0,
#  ('Heating', 'GasA'): 183536.27105263158,
#  ('Heating', 'GasW'): 160650.0,
#  ('Heating', 'Grav'): 71733.33333333333,
#  ('Heating', 'OthW'): 125750.0,
#  ('Heating', 'Wall'): 92800.0,
#  ('HeatingQC', 'Ex'): 217425.5472972973,
#  ('HeatingQC', 'Fa'): 126494.0243902439,
#  ('HeatingQC', 'Gd'): 158080.5806451613,
#  ('HeatingQC', 'Po'): 87000.0,
#  ('HeatingQC', 'TA'): 142075.8103448276,
#  ('HouseStyle', '1.5Fin'): 142139.83076923076,
#  ('HouseStyle', '1.5Unf'): 112011.11111111111,
#  ('HouseStyle', '1Story'): 176133.39794168097,
#  ('HouseStyle', '2.5Fin'): 252400.0,
#  ('HouseStyle', '2.5Unf'): 158211.11111111112,
#  ('HouseStyle', '2Story'): 214415.3654390935,
#  ('HouseStyle', 'SFoyer'): 130859.14285714286,
#  ('HouseStyle', 'SLvl'): 169096.4705882353,
#  ('KitchenQual', 'Ex'): 328107.0,
#  ('KitchenQual', 'Fa'): 107054.46875,
#  ('KitchenQual', 'Gd'): 214968.01470588235,
#  ('KitchenQual', 'TA'): 139371.50172413792,
#  ('LandContour', 'Bnk'): 143960.3469387755,
#  ('LandContour', 'HLS'): 239171.38888888888,
#  ('LandContour', 'Low'): 218250.0,
#  ('LandContour', 'Lvl'): 181028.32098765433,
#  ('LandSlope', 'Gtl'): 180906.90433212995,
#  ('LandSlope', 'Mod'): 204545.2857142857,
#  ('LandSlope', 'Sev'): 215180.0,
#  ('LotConfig', 'Corner'): 182591.7397260274,
#  ('LotConfig', 'CulDSac'): 225533.9,
#  ('LotConfig', 'FR2'): 181591.66666666666,
#  ('LotConfig', 'FR3'): 261000.0,
#  ('LotConfig', 'Inside'): 177777.98429951692,
#  ('LotShape', 'IR1'): 207176.83544303797,
#  ('LotShape', 'IR2'): 243622.58823529413,
#  ('LotShape', 'IR3'): 218691.66666666666,
#  ('LotShape', 'Reg'): 165408.6383561644,
#  ('MSZoning', 'C (all)'): 74660.0,
#  ('MSZoning', 'FV'): 220056.23529411765,
#  ('MSZoning', 'RH'): 131033.4,
#  ('MSZoning', 'RL'): 192134.5657327586,
#  ('MSZoning', 'RM'): 125164.8538011696,
#  ('MasVnrType', nan): 263393.5,
#  ('MasVnrType', 'BrkCmn'): 151564.25,
#  ('MasVnrType', 'BrkFace'): 206607.62395543174,
#  ('MasVnrType', 'None'): 157415.34487734488,
#  ('MasVnrType', 'Stone'): 267012.33,
#  ('MiscFeature', nan): 183378.2661934339,
#  ('MiscFeature', 'Gar2'): 190000.0,
#  ('MiscFeature', 'Othr'): 55000.0,
#  ('MiscFeature', 'Shed'): 151852.38461538462,
#  ('Neighborhood', 'Blmngtn'): 193494.76923076922,
#  ('Neighborhood', 'Blueste'): 137500.0,
#  ('Neighborhood', 'BrDale'): 103740.0,
#  ('Neighborhood', 'BrkSide'): 130719.88636363637,
#  ('Neighborhood', 'ClearCr'): 205313.28,
#  ('Neighborhood', 'CollgCr'): 197088.82113821138,
#  ('Neighborhood', 'Crawfor'): 206823.97368421053,
#  ('Neighborhood', 'Edwards'): 130827.46835443038,
#  ('Neighborhood', 'Gilbert'): 195660.6984126984,
#  ('Neighborhood', 'IDOTRR'): 99276.7741935484,
#  ('Neighborhood', 'MeadowV'): 99050.0,
#  ('Neighborhood', 'Mitchel'): 155888.4,
#  ('Neighborhood', 'NAmes'): 146656.6277777778,
#  ('Neighborhood', 'NPkVill'): 143291.66666666666,
#  ('Neighborhood', 'NWAmes'): 184584.9107142857,
#  ('Neighborhood', 'NoRidge'): 341651.5675675676,
#  ('Neighborhood', 'NridgHt'): 313617.7049180328,
#  ('Neighborhood', 'OldTown'): 126644.83516483517,
#  ('Neighborhood', 'SWISU'): 140134.35294117648,
#  ('Neighborhood', 'Sawyer'): 136980.56140350876,
#  ('Neighborhood', 'SawyerW'): 188765.14285714287,
#  ('Neighborhood', 'Somerst'): 226398.4776119403,
#  ('Neighborhood', 'StoneBr'): 313937.2173913043,
#  ('Neighborhood', 'Timber'): 243615.86666666667,
#  ('Neighborhood', 'Veenker'): 243250.0,
#  ('PavedDrive', 'N'): 113597.74285714286,
#  ('PavedDrive', 'P'): 132092.3076923077,
#  ('PavedDrive', 'Y'): 187918.1968283582,
#  ('PoolQC', nan): 181678.3324742268,
#  ('PoolQC', 'Ex'): 745000.0,
#  ('PoolQC', 'Fa'): 181000.0,
#  ('PoolQC', 'Gd'): 217485.0,
#  ('RoofMatl', 'ClyTile'): 160000.0,
#  ('RoofMatl', 'CompShg'): 181006.1825327511,
#  ('RoofMatl', 'Membran'): 241500.0,
#  ('RoofMatl', 'Metal'): 180000.0,
#  ('RoofMatl', 'Roll'): 137000.0,
#  ('RoofMatl', 'Tar&Grv'): 178347.0,
#  ('RoofMatl', 'WdShake'): 254250.0,
#  ('RoofMatl', 'WdShngl'): 412700.0,
#  ('RoofStyle', 'Flat'): 185451.81818181818,
#  ('RoofStyle', 'Gable'): 172666.14472252448,
#  ('RoofStyle', 'Gambrel'): 167080.0,
#  ('RoofStyle', 'Hip'): 221127.718061674,
#  ('RoofStyle', 'Mansard'): 158250.0,
#  ('RoofStyle', 'Shed'): 225000.0,
#  ('SaleCondition', 'Abnorml'): 147103.44047619047,
#  ('SaleCondition', 'AdjLand'): 104125.0,
#  ('SaleCondition', 'Alloca'): 144312.9,
#  ('SaleCondition', 'Family'): 156423.07692307694,
#  ('SaleCondition', 'Normal'): 177055.7991675338,
#  ('SaleCondition', 'Partial'): 275355.2916666667,
#  ('SaleType', 'COD'): 146884.2105263158,
#  ('SaleType', 'CWD'): 228133.33333333334,
#  ('SaleType', 'Con'): 269600.0,
#  ('SaleType', 'ConLD'): 138628.5,
#  ('SaleType', 'ConLI'): 200390.0,
#  ('SaleType', 'ConLw'): 122333.33333333333,
#  ('SaleType', 'New'): 277191.27659574465,
#  ('SaleType', 'Oth'): 119850.0,
#  ('SaleType', 'WD'): 175035.41600790515,
#  ('Street', 'Grvl'): 110438.6,
#  ('Street', 'Pave'): 182529.97076526226,
#  ('Utilities', 'AllPub'): 182259.6820908312,
#  ('Utilities', 'NoSeWa'): 137500.0}
